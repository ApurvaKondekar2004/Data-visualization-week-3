# %%
import pandas as pd

# %%
df=pd.read_csv('BlackFriday.csv')
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df['Product_Category_2'].isnull().sum()
# Out:
# 166986

# %%
df['Product_Category_3'].isnull().sum()
# Out:
# 373299

# %%
del df['Product_Category_3']

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
#how many unique users are there
n=df['User_ID'].nunique()
n
# Out:
# 5891

# %%
#how many products are there
n=df['Product_ID'].nunique()
n
# Out:
# 3623

# %%
for i in df.columns:
    print(i,df[i].nunique())
# Out:
# User_ID 5891
# Product_ID 3623
# Gender 2
# Age 7
# Occupation 21
# City_Category 3
# Stay_In_Current_City_Years 5
# Marital_Status 2
# Product_Category_1 18
# Purchase 17959

# %%
#how many males are there and how many females are there
f=0
m=0
for i in df['Gender']:
    if i=='M':
        m+=1
    else:
        f+=1
print('number of males:',m)
print('number of females:',f)
# Out:
# number of males: 405380
# number of females: 132197

# %%
df[df['Gender']=='M']
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 4                              4+               0                   8
# ...

# %%
len(df[df['Gender']=='M'])
# Out:
# 405380

# %%
#creating a special dataframe for gender
data=pd.DataFrame({'Ratio' : [len(df[df['Gender']=='M']),len(df[df['Gender']=='F'])]},index=['Males','Females'])
data
# Out:
#           Ratio
# Males    405380
# Females  132197

# %% [markdown]
# THE NUMBER OF MALES AND FEMALES

# %%
data.plot(kind='pie',y='Ratio',figsize=(6,6),autopct="%0.1f")

## So this pie chart is giving us the ratio of how many males and females shopped at black friday(the ratio of men is more as compared to women)
# Out:
# <Axes: ylabel='Ratio'>

# %%
df.groupby('Gender').size().plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %% [markdown]
# HOW MUCH MALES HAVE SPENT IN COMPARISON WITH FEMALES

# %%
df.groupby('Gender')['Purchase'].sum().plot(kind='pie',autopct="%0.1f")

## This graph tells males have purchased more as compared to females
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Gender')['Purchase'].mean().plot(kind='pie',autopct="%0.1f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
#on the basis of age
df.groupby('Age').size().plot(kind='pie',autopct="%0.1f")

##The age group involved in black friday sale is more from age group 26-35
# Out:
# <Axes: >

# %%
df.groupby('Age')['Purchase'].sum().plot(kind='pie',autopct="%0.1f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Marital_Status').size().plot(kind='pie')

# many are unmarried
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
sns.countplot(x='Age',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x='Gender',hue='Age',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x=df['City_Category'])

##Maximum people belong to B city_category
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
sns.countplot(x=df['Stay_In_Current_City_Years'])

##maximum people have stayed 1 year in the current city
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue='Gender',data=df)

#Maximum are males who have stayed in the city
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby('Stay_In_Current_City_Years')['Purchase'].sum().plot(kind='pie',autopct='%0.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
sns.countplot(x=df['Occupation'])

##Occupation number 4 has more count
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').size().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation')['Purchase'].sum().sort_values().plot(kind='bar')

##The purchase is also more of occupation no 4
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation')['Purchase'].mean().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
sns.countplot(x='Occupation',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').nunique()['Product_ID'].plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Product_Category_1').size().nlargest(10).sort_values().plot(kind='bar')

##The product category 1 item no 5 is being purchased more
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
l=[]
for i in range(len(df)):
    l.append(df['Gender'][i] +"_"+ str(df['Marital_Status'][i]))

df['MaritalGender']=l

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase MaritalGender
# 0                 NaN                 NaN      8370           F_0
# 1                 6.0                14.0     15200           F_0
# ...

# %%
sns.countplot(x=df['MaritalGender'])
# Out:
# <Axes: xlabel='MaritalGender', ylabel='count'>

# %%
sns.countplot(x=df['MaritalGender'],hue=df['Age'])
# Out:
# <Axes: xlabel='MaritalGender', ylabel='count'>

# %%
sns.countplot(x=df['Stay_In_Current_City_Years'],hue=df['MaritalGender'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>
